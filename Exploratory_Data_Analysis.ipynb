# %%
# Importing necessary libraries

# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('air_pollution_data.csv')

# %%
# Display the first few rows of the dataset
print("First few rows of the dataset:")
display(df.head())
# Out:
# First few rows of the dataset:
#                     dt  main_aqi      co   no   no2     o3   so2  pm2_5  pm10  \
# 0  2024-01-01 05:00:00         2  270.37  0.0  3.04  68.66  0.69    0.5  0.78
# 1  2024-01-01 06:00:00         2  263.69  0.0  2.23  70.81  0.60    0.5  0.71
# 2  2024-01-01 07:00:00         2  257.02  0.0  1.74  70.81  0.53    0.5  0.67
# 3  2024-01-01 08:00:00         2  250.34  0.0  1.48  70.81  0.48    0.5  0.67
# 4  2024-01-01 09:00:00         2  247.00  0.0  1.33  71.53  0.45    0.5  0.67
#
#     nh3
# 0  1.01
# 1  0.85
# 2  0.78
# 3  0.82
# 4  0.85

# %%
# Summary statistics
print("Summary statistics:")
display(df.describe())
# Out:
# Summary statistics:
#          main_aqi          co          no         no2          o3         so2  \
# count  864.000000  864.000000  864.000000  864.000000  864.000000  864.000000
# mean     1.444444  333.967465    0.670799   14.091470   48.075486    4.424062
# std      0.497192   74.017285    1.789977   12.436035   18.049054    4.472085
# min      1.000000  236.990000    0.000000    1.150000    3.260000    0.150000
# 25%      1.000000  280.380000    0.000000    4.410000   36.120000    0.970000
# 50%      1.000000  313.760000    0.020000    9.470000   51.500000    2.180000
# 75%      2.000000  363.830000    0.440000   20.560000   61.510000    7.405000
# max      2.000000  660.900000   16.760000   62.380000   82.970000   18.120000
#
#            pm2_5       pm10         nh3
# count  864.00000  864.00000  864.000000
# mean     4.40397    5.88191    2.029398
# std      4.19813    5.34655    2.311582
# min      0.50000    0.57000    0.070000
# 25%      1.06500    1.61000    0.607500
# 50%      2.78000    4.26000    1.225000
# 75%      6.66250    8.37500    2.630000
# max     18.58000   25.09000   15.450000

# %%
# Data types and missing values
print("Data types and missing values:")
display(df.info())
# Out:
# Data types and missing values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   dt        864 non-null    object
#  1   main_aqi  864 non-null    int64
#  2   co        864 non-null    float64
#  3   no        864 non-null    float64
#  4   no2       864 non-null    float64
#  5   o3        864 non-null    float64
#  6   so2       864 non-null    float64
#  7   pm2_5     864 non-null    float64
#  8   pm10      864 non-null    float64
#  9   nh3       864 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 67.6+ KB
# None

# %%
# Correlation matrix
numeric_df = df.select_dtypes(include=['int64', 'float64'])
print("Correlation matrix:")
display(numeric_df.corr())
# Out:
# Correlation matrix:
#           main_aqi        co        no       no2        o3       so2  \
# main_aqi  1.000000 -0.069039  0.046252  0.082115  0.300224  0.139666
# co       -0.069039  1.000000  0.296373  0.842067 -0.836381  0.491257
# no        0.046252  0.296373  1.000000  0.275282 -0.157707  0.407195
# no2       0.082115  0.842067  0.275282  1.000000 -0.713184  0.806458
# o3        0.300224 -0.836381 -0.157707 -0.713184  1.000000 -0.335245
# so2       0.139666  0.491257  0.407195  0.806458 -0.335245  1.000000
# pm2_5     0.161429  0.697877  0.304478  0.736272 -0.676798  0.573656
# pm10      0.174613  0.761000  0.344590  0.836635 -0.696636  0.673526
# nh3      -0.064505  0.520006  0.078971  0.412690 -0.325744  0.340590
#
#              pm2_5      pm10       nh3
# main_aqi  0.161429  0.174613 -0.064505
# co        0.697877  0.761000  0.520006
# no        0.304478  0.344590  0.078971
# no2       0.736272  0.836635  0.412690
# o3       -0.676798 -0.696636 -0.325744
# so2       0.573656  0.673526  0.340590
# pm2_5     1.000000  0.976447  0.270878
# pm10      0.976447  1.000000  0.342097
# nh3       0.270878  0.342097  1.000000

# %%
# Histograms of numeric variables
print("Histograms of numeric variables:")
df.hist(figsize=(12, 8))
plt.tight_layout()
plt.show()
# Out:
# Histograms of numeric variables:

# %%
# Box plots of numeric variables
print("Box plots of numeric variables:")
df.boxplot(figsize=(20, 10))
plt.xticks(rotation=0)
plt.ylim(0, 700)
plt.tight_layout()
plt.show()
# Out:
# Box plots of numeric variables:

# %%
except_co_df = df.drop(columns=['co'])
print("Box plots of numeric variables:")
except_co_df.boxplot(figsize=(20, 10))
plt.xticks(rotation=0)
plt.ylim(0, 100)
plt.tight_layout()
plt.show()
# Out:
# Box plots of numeric variables:

# %%
# Pairplot of numeric variables
print("Pairplot of numeric variables:")
sns.pairplot(df)
plt.show()
# Out:
# Pairplot of numeric variables:
